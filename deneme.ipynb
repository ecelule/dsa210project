# %% [markdown]
# # Running Heart Rate Analysis
# This notebook will explore how heart rate changes during running.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd

df = pd.read_csv("data/archive/s1_summaries.csv")

df.head()
# Out:
#    event_id  lat_median  long_median         timezone  heart_rate_median  \
# 0         1   41.966027   -87.646939  America/Chicago              151.0
# 1         2   41.975176   -87.650256  America/Chicago              158.0
# 2         3   41.964429   -87.642942  America/Chicago              161.0
# 3         4   41.940418   -87.637683  America/Chicago              148.0
# 4         5   41.965287   -87.648160  America/Chicago              161.0
#
#    heart_rate_50w  heart_rate_10  heart_rate_25  heart_rate_75  heart_rate_90  \
# 0      150.352473          137.0          144.0          153.0          155.0
# 1      157.631892          144.0          152.0          161.0          162.0
# 2      160.624177          133.5          151.0          166.0          169.0
# 3      148.030029          143.0          146.0          156.0          159.0
# 4      160.438884          148.0          155.0          165.0          166.0
#
# ...

# %%
df.columns
# Out:
# Index(['event_id', 'lat_median', 'long_median', 'timezone',
#        'heart_rate_median', 'heart_rate_50w', 'heart_rate_10', 'heart_rate_25',
#        'heart_rate_75', 'heart_rate_90',
#        ...
#        'speed_proportion__16_17', 'speed_proportion__17_18',
#        'speed_proportion__18_19', 'speed_proportion__19_20',
#        'speed_proportion__20_22', 'speed_proportion__22_25',
#        'speed_proportion__25', 'total_time_spent_running',
#        'proportion_time_spent_running', 'proportion_rest_time'],
#       dtype='object', length=145)

# %%
import pandas as pd

df2 = pd.read_csv("data/Strava Running Data.csv")
df2.head()
# Out:
#    Sr. no.      start_date_local type  distance  moving_time  elapsed_time  \
# 0        1  2023-12-09T09:09:19Z  Run   10879.7         4023          4617
# 1        2  2023-12-07T17:31:50Z  Run    1304.4          722         62993
# 2        3  2023-12-03T09:18:13Z  Run   17503.0         7370          7462
# 3        4  2023-12-02T09:41:14Z  Run    3457.8         1791          2170
# 4        5  2023-12-01T17:06:05Z  Run   10108.2         4128          4221
#
#    total_elevation_gain                             start_latlng  \
# 0                  91.4  [40.70327935740352, -73.99619171395898]
# 1                   0.0   [40.7220459356904, -74.03641730546951]
# 2                  68.4  [40.74991073459387, -73.98751585744321]
# 3                   3.9  [40.72203076444566, -74.03641068376601]
# 4                   6.3  [40.72190687991679, -74.03624514117837]
#
#                                  end_latlng sport_type            start_date  \
# ...

# %%
df2.columns
# Out:
# Index(['Sr. no.', 'start_date_local', 'type', 'distance', 'moving_time',
#        'elapsed_time', 'total_elevation_gain', 'start_latlng', 'end_latlng',
#        'sport_type', 'start_date', 'timezone', 'achievement_count',
#        'kudos_count', 'comment_count', 'athlete_count', 'photo_count',
#        'average_speed', 'max_speed'],
#       dtype='object')

# %%
df3 = pd.read_csv("data/activity_log.csv")
df3.head()
# Out:
#   Activity Type           Date                Title  Distance Calories  \
# 0       Running   7/15/20 9:41  Cherry Hill Running      6.00      530
# 1       Running  7/14/20 17:45  Cherry Hill Running      6.50      587
# 2       Running  7/13/20 18:57  Cherry Hill Running      5.01      392
# 3       Running  7/12/20 18:44  Cherry Hill Running      7.01      633
# 4       Running  7/11/20 19:35  Cherry Hill Running      5.19      419
#
#       Time Avg HR Max HR Avg Run Cadence Max Run Cadence Avg Pace Best Pace  \
# 0  0:43:55    141    160             176             182     7:19      6:20
# 1  0:47:04    144    160             172             182     7:14      6:35
# 2  0:40:29    128    151             170             180     8:05      5:49
# 3  0:52:55    142    157             172             180     7:33      5:00
# 4  0:41:35    129    143             170             178     8:01      6:48
#
#   Elev Gain Elev Loss  Avg Stride Length Best Lap Time  Number of Laps
# ...

# %%
df3.columns
# Out:
# Index(['Activity Type', 'Date', 'Title', 'Distance', 'Calories', 'Time',
#        'Avg HR', 'Max HR', 'Avg Run Cadence', 'Max Run Cadence', 'Avg Pace',
#        'Best Pace', 'Elev Gain', 'Elev Loss', 'Avg Stride Length',
#        'Best Lap Time', 'Number of Laps'],
#       dtype='object')

# %%
import pandas as pd

file_path = "UNIGME-2025-UNICEFRegion-Rates-Deaths-Sex-specific-5-to-24.xlsx"

xls = pd.ExcelFile(file_path)
print(xls.sheet_names)
# Out:
# ['10q5, 5q5, 5q10', '10q15, 5q15, 5q20', '20q5, 10q10']

# %%
import pandas as pd

file_path = "UNIGME-2025-UNICEFRegion-Rates-Deaths-Sex-specific-5-to-24.xlsx"

df = pd.read_excel(file_path, sheet_name="10q5, 5q5, 5q10")
df.head()
# Out:
#                            Child Mortality Estimates Unnamed: 1 Unnamed: 2  \
# 0  Global and regional probability of dying among...        NaN        NaN
# 1  Estimates generated by the UN Inter-agency Gro...        NaN        NaN
# 2          downloaded from http://childmortality.org        NaN        NaN
# 3                           Last updated: March 2026        NaN        NaN
# 4                 Contact: childmortality@unicef.org        NaN        NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 9  ... Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15  \
# ...

# %%
import pandas as pd

file_path = "UNIGME-2025-UNICEFRegion-Rates-Deaths-Sex-specific-5-to-24.xlsx"

df = pd.read_excel(file_path, sheet_name="10q5, 5q5, 5q10", skiprows=13)
df.head()
# Out:
#            Unnamed: 0 Unnamed: 1 Unnamed: 2       10q5 Unnamed: 4 Unnamed: 5  \
# 0              Region        Sex       Year      Lower     Median      Upper
# 1  Sub-Saharan Africa     Female       1990  34.806161  36.566717  39.480004
# 2  Sub-Saharan Africa     Female       1991  34.969822  36.632261  39.304716
# 3  Sub-Saharan Africa     Female       1992  35.631654  37.219232   39.69722
# 4  Sub-Saharan Africa     Female       1993  35.314504  36.794675  39.089802
#
#          5q5 Unnamed: 7 Unnamed: 8       5q10  ... Unnamed: 11  \
# 0      Lower     Median      Upper      Lower  ...       Upper
# 1  23.105663  24.299886  25.650615  10.511411  ...   15.623417
# 2  23.100183  24.221984  25.553441  10.797239  ...   15.451814
# 3  23.319529  24.389552  25.708757  11.343801  ...   15.640816
# 4  22.986071  23.980781  25.257769  11.467377  ...   15.425764
#
#   Deaths age 5 to 14 Unnamed: 13 Unnamed: 14 Deaths age 5 to 9 Unnamed: 16  \
# ...

# %%
df.columns
df.head()
df.shape
# Out:
# (841, 21)
